# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv("teleCust1000t.csv")

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.head()
# Out:
#    region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0       2      13   44        1        9    64.0   4       5     0.0       0
# 1       3      11   33        1        7   136.0   5       5     0.0       0
# 2       3      68   52        1       24   116.0   1      29     0.0       1
# 3       2      33   33        0       12    33.0   2       0     0.0       1
# 4       2      23   30        1        9    30.0   1       2     0.0       0
#
#    reside  custcat
# 0       2        1
# 1       6        4
# 2       2        3
# 3       1        1
# 4       4        3

# %%
data["custcat"].value_counts()
# Out:
# 3    281
# 1    266
# 4    236
# 2    217
# Name: custcat, dtype: int64

# %%
data.groupby("custcat").income.mean()
# Out:
# custcat
# 1    54.759398
# 2    74.834101
# 3    89.032028
# 4    92.000000
# Name: income, dtype: float64

# %%
sns.countplot(data["custcat"],hue=data["region"])

# %%
data.columns
# Out:
# Index(['region', 'tenure', 'age', 'marital', 'address', 'income', 'ed',
#        'employ', 'retire', 'gender', 'reside', 'custcat'],
#       dtype='object')

# %%
x=data[data.columns[:-1]]

# %%
x
# Out:
#      region  tenure  age  marital  address  income  ed  employ  retire  \
# 0         2      13   44        1        9    64.0   4       5     0.0
# 1         3      11   33        1        7   136.0   5       5     0.0
# 2         3      68   52        1       24   116.0   1      29     0.0
# 3         2      33   33        0       12    33.0   2       0     0.0
# 4         2      23   30        1        9    30.0   1       2     0.0
# 5         2      41   39        0       17    78.0   2      16     0.0
# 6         3      45   22        1        2    19.0   2       4     0.0
# 7         2      38   35        0        5    76.0   2      10     0.0
# 8         3      45   59        1        7   166.0   4      31     0.0
# 9         1      68   41        1       21    72.0   1      22     0.0
# 10        2       5   33        0       10   125.0   4       5     0.0
# 11        3       7   35        0       14    80.0   2      15     0.0
# ...

# %%
y=data["custcat"]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
knn=KNeighborsClassifier(38)

# %%
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_y,test_y=train_test_split(x_scaled,y,test_size=0.3,random_state=101)

# %%
train_x.shape
# Out:
# (700, 11)

# %%
knn.fit(train_x,train_y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=38, p=2,
#                      weights='uniform')

# %%
train_pred=knn.predict(train_x)

# %%
test_pred=knn.predict(test_x)

# %%
print(accuracy_score(train_y,train_pred))
# Out:
# 0.4114285714285714

# %%
print(accuracy_score(test_y,test_pred))
# Out:
# 0.3333333333333333

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()

# %%
x_scaled=scale.fit_transform(x)

# %%
error=[]

for i in range(1,50):
    knn=KNeighborsClassifier(i)
    knn.fit(train_x,train_y)
    pred_i=knn.predict(test_x)
    error.append(np.mean(test_y !=pred_i))

# %%
error
# Out:
# [0.0,
#  0.37,
#  0.42142857142857143,
#  0.4471428571428571,
#  0.4685714285714286,
#  0.49,
#  0.5114285714285715,
#  0.5257142857142857,
#  0.5171428571428571,
#  0.5471428571428572,
#  0.54,
#  0.5442857142857143,
#  0.5542857142857143,
#  0.5542857142857143,
#  0.5685714285714286,
#  0.5557142857142857,
#  0.5628571428571428,
#  0.5614285714285714,
#  0.5614285714285714,
#  0.5642857142857143,
#  0.5757142857142857,
#  0.5657142857142857,
#  0.5557142857142857,
#  0.56,
#  0.5571428571428572,
#  0.5614285714285714,
#  0.5628571428571428,
#  0.5685714285714286,
#  0.5685714285714286,
#  0.5642857142857143,
#  0.57,
#  0.5642857142857143,
#  0.5657142857142857,
#  0.57,
#  0.5757142857142857,
#  0.5842857142857143,
#  0.5828571428571429,
#  0.5885714285714285,
#  0.5771428571428572,
#  0.5857142857142857,
#  0.5842857142857143,
#  0.58,
#  0.5842857142857143,
#  0.5828571428571429,
#  0.5885714285714285,
#  0.5871428571428572,
#  0.5857142857142857,
#  0.5871428571428572,
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(1,50),error,marker="o",linestyle="dashed",markerfacecolor="red")
